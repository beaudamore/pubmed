# %% [markdown]
# # PubMed Oncology MedGemma 27B Text SFT Fine-Tuning with Unsloth (4-bit QLoRA)
#
# **Base Model:** MedGemma 27B Text IT (4-bit quantized) — Google's medical text LLM built on Gemma 3
#
# **Dataset:** PubMed oncology datagen JSONL — multi-turn QA, continuation, treatment reasoning, beyond-evidence, and self-correction conversations across 11 cancer types
#
# **Training Hardware:** NVIDIA DGX Spark (128GB unified memory)
#
# **Inference Hardware:** NVIDIA A5000 24GB (~14GB weights + overhead fits comfortably)
#
# **Chat Template:** Gemma 3 format — `<start_of_turn>role\ncontent<end_of_turn>`
#
# **Architecture:** This is Phase 1 (SFT). Teaches the model clinical oncology reasoning. Phase 2 (DPO) refines response quality using preference pairs.
#
# ## How to run
# **Press "Run All" and walk away.** Every cell is self-contained and runs in order.

# %% [markdown]
# ## 1. Setup — Configuration, Environment, GPU Check
#
# Installs missing packages, verifies GPU, sets all paths and hyperparameters. Safe to re-run.

# %%
import os, sys, subprocess, importlib, importlib.util

# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║  CRITICAL: Disable Unsloth's FlexAttention for Gemma 3 on Blackwell         ║
# ║                                                                              ║
# ║  Unsloth's prefer_flex_attn_if_supported() forces flex_attention on Gemma 3, ║
# ║  overriding the default attention. FlexAttention's backward pass uses   ║
# ║  Triton kernels that exceed shared memory on sm_120 (Blackwell).             ║
# ║  Setting this to "0" prevents the override — Unsloth uses fast eager instead.           ║
# ║  All other torch.compile optimizations (fused LM head, fast LoRA, etc.)      ║
# ║  remain active.                                                              ║
# ║  MUST be set BEFORE `import unsloth`.                                        ║
# ╚══════════════════════════════════════════════════════════════════════════════╝
os.environ["UNSLOTH_ENABLE_FLEX_ATTENTION"] = "0"

# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║  STEP 1: INSTALL MISSING PACKAGES (safe to re-run, never clobbers NGC torch)║
# ║                                                                              ║
# ║  ORDER MATTERS:                                                              ║
# ║    1. torch check (no side effects)                                          ║
# ║    2. pip install small packages                                             ║
# ║    3. fix causal_conv1d (NGC ships broken build w/o CUDA extension)          ║
# ║    4. import unsloth FIRST (BEFORE transformers — required for patching)     ║
# ╚══════════════════════════════════════════════════════════════════════════════╝

def _pip(*args, env_extra=None):
    cmd = [sys.executable, "-m", "pip"] + list(args)
    env = os.environ.copy()
    if env_extra:
        env.update(env_extra)
    result = subprocess.run(cmd, capture_output=True, text=True, env=env)
    if result.returncode != 0:
        print(f"  PIP FAILED: {' '.join(args)}")
        print(result.stderr[-500:] if result.stderr else result.stdout[-500:])
        return False
    return True

def _check_import(module_name):
    try:
        return importlib.import_module(module_name)
    except (ImportError, ModuleNotFoundError):
        return None

print("=" * 60)
print("ENVIRONMENT SETUP")
print("=" * 60)

# ── 1a. Verify NGC CUDA PyTorch is intact ──
import torch
if not torch.cuda.is_available():
    print("FATAL: torch.cuda.is_available() = False")
    print(f"  torch version: {torch.__version__}")
    if "+cpu" in torch.__version__ or "cpu" in torch.__version__:
        print("  NGC CUDA PyTorch was clobbered by pip. Recreate the container.")
    else:
        print("  GPU not passed through. Check Portainer: runtime=nvidia, NVIDIA_VISIBLE_DEVICES=all")
    raise RuntimeError("No GPU. Cannot continue. See messages above.")

print(f"  torch {torch.__version__} — CUDA {torch.version.cuda} — GPU: {torch.cuda.get_device_name(0)}")
print(f"  UNSLOTH_ENABLE_FLEX_ATTENTION = {os.environ.get('UNSLOTH_ENABLE_FLEX_ATTENTION')}")

# ── 1b. Small utility packages ──
for module, install_args in {
    "psutil":      ["install", "-q", "psutil"],
    "matplotlib":  ["install", "-q", "matplotlib"],
    "ipywidgets":  ["install", "-q", "ipywidgets"],
    "torchvision": ["install", "-q", "--no-deps", "torchvision"],
    "PIL":         ["install", "-q", "pillow"],
}.items():
    if _check_import(module) is None:
        print(f"  Installing {install_args[-1]}...")
        _pip(*install_args)

# ── 1c. Fix causal_conv1d ──
_causal_ok = False
_build_env = {
    "CAUSAL_CONV1D_FORCE_BUILD": "TRUE",
    "TORCH_CUDA_ARCH_LIST": "12.0;12.1",
}
try:
    from causal_conv1d.causal_conv1d_interface import causal_conv1d_fn
    _causal_ok = True
    print("  causal_conv1d: OK (CUDA extension loaded)")
    for _k in list(sys.modules.keys()):
        if "causal_conv1d" in _k:
            del sys.modules[_k]
except (ImportError, ModuleNotFoundError, OSError):
    print("  causal_conv1d: CUDA extension missing — rebuilding from source (~3 min)...")
    _pip("uninstall", "-y", "causal-conv1d")
    _pip("cache", "remove", "causal_conv1d")
    for _k in list(sys.modules.keys()):
        if "causal_conv1d" in _k:
            del sys.modules[_k]
    importlib.invalidate_caches()
    ok = _pip("install", "--no-build-isolation", "--no-deps", "--force-reinstall",
              "--no-binary", "causal-conv1d", "causal-conv1d", env_extra=_build_env)
    if ok:
        importlib.invalidate_caches()
        try:
            from causal_conv1d.causal_conv1d_interface import causal_conv1d_fn
            _causal_ok = True
            print("  causal_conv1d: rebuilt OK (CUDA extension working)")
            for _k in list(sys.modules.keys()):
                if "causal_conv1d" in _k:
                    del sys.modules[_k]
        except (ImportError, ModuleNotFoundError, OSError):
            print("  causal_conv1d: rebuild produced no CUDA ext — uninstalling for fallback")
            _pip("uninstall", "-y", "causal-conv1d")
            for _k in list(sys.modules.keys()):
                if "causal_conv1d" in _k:
                    del sys.modules[_k]
            importlib.invalidate_caches()
    else:
        print("  causal_conv1d: source build failed — uninstalling for fallback")
        _pip("uninstall", "-y", "causal-conv1d")
        importlib.invalidate_caches()

# ── 1d. Import unsloth FIRST, then transformers ──
# NOTE: UNSLOTH_ENABLE_FLEX_ATTENTION=0 is set above — unsloth reads it at import time.
for _k in list(sys.modules.keys()):
    if _k in ("transformers", "trl", "peft") or _k.startswith(("transformers.", "trl.", "peft.")):
        del sys.modules[_k]
importlib.invalidate_caches()

import unsloth
import transformers
print(f"  transformers {transformers.__version__}")

# ── 1e. Report final state ──
print()
for name, mod in [("unsloth", "unsloth"), ("transformers", "transformers"), ("trl", "trl"),
                   ("causal_conv1d", "causal_conv1d")]:
    m = _check_import(mod)
    v = getattr(m, "__version__", "installed") if m else "n/a"
    status = "OK" if m else "FALLBACK" if name == "causal_conv1d" else "MISSING"
    print(f"  {name:25s} {v:20s} [{status}]")

# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║  STEP 2: CONFIGURATION                                                      ║
# ╚══════════════════════════════════════════════════════════════════════════════╝

print()
print("=" * 60)
print("CONFIGURATION")
print("=" * 60)

# --- Paths (auto-detect Docker vs host) ---
if os.path.exists("/workspace/training/pubmed"):
    PROJECT_ROOT = "/workspace/training/pubmed"
    _env = "Docker (Unsloth container)"
elif os.path.exists("/workspace/pubmed"):
    PROJECT_ROOT = "/workspace/pubmed"
    _env = "Docker (legacy mount)"
else:
    PROJECT_ROOT = "/home/spark/projects/training/pubmed"
    _env = "Host (VS Code / venv)"

DATA_DIR    = f"{PROJECT_ROOT}/data"
OUTPUT_ROOT = f"{PROJECT_ROOT}/output/v3"

# =========================== MODEL CONFIGURATION ===========================
BASE_LLM        = "unsloth/medgemma-27b-text-it-unsloth-bnb-4bit"
MODEL_NAME_BASE = "pubmed_oncologist_v3_medgemma_sft"

# =========================== INPUT DATA ===========================
INPUT_DATA_FILE = f"{DATA_DIR}/training-data/pubmed_oncologist_v2_tool_sft_messages.jsonl"

# =========================== OUTPUT DIRECTORIES ===========================
OUTPUT_BASE_DIR     = f"{OUTPUT_ROOT}/{MODEL_NAME_BASE}"
OUTPUT_DIR_ADAPTERS = f"{OUTPUT_BASE_DIR}/train"
LORA_OUTPUT_DIR     = f"{OUTPUT_BASE_DIR}/lora_adapters"

# =========================== TRAINING HYPERPARAMETERS ===========================
MAX_SEQ_LENGTH  = 16384
BATCH_SIZE      = 2        # smaller microbatch for 27B model (matches Qwen3 SFT)
GRAD_ACCUM      = 4        # effective batch = 2 * 4 = 8
LEARNING_RATE   = 2e-4
TARGET_EPOCHS   = 1

# =========================== LoRA CONFIGURATION ===========================
LORA_R              = 32
LORA_ALPHA          = 32
LORA_DROPOUT        = 0
LORA_TARGET_MODULES = [
    "q_proj", "k_proj", "v_proj", "o_proj",
    "gate_proj", "up_proj", "down_proj",
]

# =========================== INFERENCE TEST ===========================
TEST_PROMPT = "A 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer has progressed after platinum-based chemotherapy and a PARP inhibitor. What are the next treatment options?"

# --- Print summary ---
print(f"  Environment:  {_env}")
print(f"  PROJECT_ROOT: {PROJECT_ROOT}")
print(f"  Base model:   {BASE_LLM}")
print(f"  Model name:   {MODEL_NAME_BASE}")
print(f"  Input data:   {INPUT_DATA_FILE}")
print(f"  LoRA output:  {LORA_OUTPUT_DIR}")
print(f"  LoRA:         r={LORA_R}, alpha={LORA_ALPHA}, targets={len(LORA_TARGET_MODULES)} modules")
print(f"  Training:     batch={BATCH_SIZE} x grad_accum={GRAD_ACCUM} = effective {BATCH_SIZE*GRAD_ACCUM}")
print(f"  Precision:    4-bit QLoRA (pre-quantized NF4)")

# --- Verify paths ---
for path, label in [(INPUT_DATA_FILE, "Training data"), (PROJECT_ROOT, "Project root")]:
    exists = os.path.exists(path)
    print(f"  {'OK' if exists else 'MISSING':7s} {label}: {path}")
    if not exists:
        raise FileNotFoundError(f"{label} not found: {path}")

print()
print("Setup complete. All cells below can run sequentially.")
# Out:
# ============================================================
# ENVIRONMENT SETUP
# ============================================================
#   torch 2.10.0a0+b558c986e8.nv25.11 — CUDA 13.0 — GPU: NVIDIA GB10
#   UNSLOTH_ENABLE_FLEX_ATTENTION = 0
#   causal_conv1d: OK (CUDA extension loaded)
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
#   transformers 5.10.0.dev0
#
#   unsloth                   2026.5.7             [OK]
#   transformers              5.10.0.dev0          [OK]
#   trl                       0.24.0               [OK]
#   causal_conv1d             0.0.local            [OK]
#
# ============================================================
# CONFIGURATION
# ============================================================
#   Environment:  Docker (Unsloth container)
#   PROJECT_ROOT: /workspace/training/pubmed
#   Base model:   unsloth/medgemma-27b-text-it-unsloth-bnb-4bit
#   Model name:   pubmed_oncologist_v3_medgemma_sft
#   Input data:   /workspace/training/pubmed/data/training-data/pubmed_oncologist_v2_tool_sft_messages.jsonl
#   LoRA output:  /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters
#   LoRA:         r=32, alpha=32, targets=7 modules
#   Training:     batch=2 x grad_accum=4 = effective 8
#   Precision:    4-bit QLoRA (pre-quantized NF4)
#   OK      Training data: /workspace/training/pubmed/data/training-data/pubmed_oncologist_v2_tool_sft_messages.jsonl
#   OK      Project root: /workspace/training/pubmed
#
# Setup complete. All cells below can run sequentially.

# %% [markdown]
# ## 2. Load Dataset
#
# Load the combined multi-turn ShareGPT JSONL from datagen.
#
# - 33,349 conversations across 11 cancer types
# - Data types: QA (with thinking), continuation, treatment reasoning, beyond-evidence, self-correction
# - Standard ShareGPT format: `[system, human, gpt, human, gpt, ...]`
# - System prompts are extracted from the JSONL at load time (stays in sync with datagen)

# %%
import json, os
from collections import defaultdict
from datasets import Dataset as HFDataset

print(f"LOADING TOOL-CALLING SFT DATA")
print(f"  File: {INPUT_DATA_FILE}")

# =========================== SAMPLE LIMIT FOR DIAGNOSTIC RUNS ===========================
SFT_MAX_EXAMPLES = 9000  # Set to e.g., 1000 for a rapid diagnostic test run, None = use full file
# ========================================================================================

raw_rows = []
cancer_type_counts = defaultdict(int)
source_counts = defaultdict(int)
system_prompts_by_cancer = {}  # cancer_type -> system prompt text

with open(INPUT_DATA_FILE) as f:
    for line in f:
        row = json.loads(line)

        cancer = row.get("cancer_type", "unknown")
        source = row.get("source", "unknown")
        cancer_type_counts[cancer] += 1
        source_counts[source] += 1

        # Keep messages format intact for tool-calling SFT.
        if "messages" in row:
            raw_rows.append({"messages": row["messages"]})
            # Extract system prompt if first message is system
            if row["messages"] and row["messages"][0].get("role") == "system":
                sys_msg = row["messages"][0].get("content", "")
                if sys_msg and cancer not in system_prompts_by_cancer:
                    system_prompts_by_cancer[cancer] = sys_msg
        elif "conversations" in row:
            raw_rows.append({"conversations": row["conversations"]})
            # Extract system prompt if first turn is system
            if row["conversations"] and row["conversations"][0].get("from") == "system":
                sys_msg = row["conversations"][0].get("value", "")
                if sys_msg and cancer not in system_prompts_by_cancer:
                    system_prompts_by_cancer[cancer] = sys_msg
        else:
            raise ValueError("Row missing both 'messages' and 'conversations'")

# Apply sample limit if configured
if SFT_MAX_EXAMPLES is not None and len(raw_rows) > SFT_MAX_EXAMPLES:
    print(f"  Capping raw dataset size from {len(raw_rows):,} to SFT_MAX_EXAMPLES={SFT_MAX_EXAMPLES:,}")
    raw_rows = raw_rows[:SFT_MAX_EXAMPLES]

dataset = HFDataset.from_list(raw_rows)

print(f"\n{'='*50}")
print(f"Total dataset: {len(dataset)} conversations")
print(f"Cancer types: {len(cancer_type_counts)}")
print(f"Sources: {len(source_counts)}")
print(f"Unique system prompts: {len(system_prompts_by_cancer)}")
print(f"Columns: {dataset.column_names}")

print(f"\nPer-cancer breakdown (entire file):")
for ct, c in sorted(cancer_type_counts.items(), key=lambda x: -x[1]):
    print(f"  {ct:30s} {c:>5d} conversations")

print(f"\nPer-source breakdown:")
for src, c in sorted(source_counts.items(), key=lambda x: -x[1]):
    print(f"  {src:30s} {c:>5d} rows")
# Out:
# LOADING TOOL-CALLING SFT DATA
#   File: /workspace/training/pubmed/data/training-data/pubmed_oncologist_v2_tool_sft_messages.jsonl
#   Capping raw dataset size from 19,293 to SFT_MAX_EXAMPLES=9,000
#
# ==================================================
# Total dataset: 9000 conversations
# Cancer types: 11
# Sources: 2
# Unique system prompts: 11
# Columns: ['messages']
#
# Per-cancer breakdown (entire file):
#   pubmed_brain_tumour             1788 conversations
#   pubmed_bone_cancer              1788 conversations
#   pubmed_prostate_cancer          1787 conversations
#   pubmed_lung_cancer              1787 conversations
#   pubmed_colon_cancer             1787 conversations
#   pubmed_ovarian_cancer           1787 conversations
#   pubmed_skin_cancer              1787 conversations
#   pubmed_breast_cancer            1787 conversations
#   pubmed_kidney_cancer            1721 conversations
#   pubmed_gastric_cancer           1694 conversations
#   cancerguide_treatment_reasoning  1580 conversations
#
# Per-source breakdown:
#   tool_calling_augmentation       9647 rows
#   direct_response_with_tools_available  9646 rows

# %% [markdown]
# ## 3. Validate & Summarize Dataset
#
# Verify data quality: turn structure, non-empty responses, thinking tag presence.

# %%
from collections import Counter

bad_examples = []
empty_final_responses = []
tool_call_examples = 0

def _get_messages(example):
    if "messages" in example:
        return example["messages"]
    if "conversations" in example:
        # Fallback support for ShareGPT rows.
        role_map = {"system": "system", "human": "user", "gpt": "assistant"}
        return [{"role": role_map[t["from"]], "content": t["value"]} for t in example["conversations"]]
    raise ValueError("Example missing both messages and conversations")

for i, example in enumerate(dataset):
    msgs = _get_messages(example)

    if len(msgs) < 3:
        bad_examples.append((i, f"Expected >=3 messages, got {len(msgs)}"))
        continue

    # Must start with system, then user for this training format.
    if msgs[0].get("role") != "system" or msgs[1].get("role") != "user":
        bad_examples.append((i, "Expected first two roles to be system,user"))
        continue

    # Final assistant content must be non-empty.
    last = msgs[-1]
    if last.get("role") != "assistant" or not str(last.get("content", "")).strip():
        empty_final_responses.append(i)

    # Track explicit tool-calling examples.
    has_tool_call = any(m.get("role") == "assistant" and m.get("tool_calls") for m in msgs)
    if has_tool_call:
        tool_call_examples += 1

role_seq_dist = Counter(tuple(m.get("role") for m in _get_messages(ex)) for ex in dataset)

print("DATA QUALITY CHECK")
print(f"  Total examples: {len(dataset)}")
print(f"  Bad structure: {len(bad_examples)}")
print(f"  Empty final responses: {len(empty_final_responses)}")
print(f"  With explicit tool_calls: {tool_call_examples} ({100*tool_call_examples/len(dataset):.1f}%)")
print(f"  Without explicit tool_calls: {len(dataset)-tool_call_examples} ({100*(len(dataset)-tool_call_examples)/len(dataset):.1f}%)")

print(f"\nTop role sequences (up to 5):")
for seq, n in role_seq_dist.most_common(5):
    print(f"  {seq} -> {n}")

if bad_examples:
    print(f"\n  Bad examples (first 5):")
    for idx, reason in bad_examples[:5]:
        print(f"    Example {idx}: {reason}")

if empty_final_responses:
    print(f"\n  Filtering {len(empty_final_responses)} rows with empty/non-assistant final response...")
    bad_set = set(empty_final_responses)
    good_indices = [i for i in range(len(dataset)) if i not in bad_set]
    dataset = dataset.select(good_indices)
    print(f"  Dataset after filtering: {len(dataset)} examples")

print(f"\nCANCER TYPE DISTRIBUTION:")
max_name_len = max(len(n) for n in cancer_type_counts)
for name, count in sorted(cancer_type_counts.items(), key=lambda x: -x[1]):
    bar = "#" * max(1, count // 200)
    print(f"  {name:<{max_name_len}} {count:>5}  {bar}")
print(f"  {'TOTAL':<{max_name_len}} {sum(cancer_type_counts.values()):>5}")

print(f"\nDataset validated and ready for training")
# Out:
# DATA QUALITY CHECK
#   Total examples: 9000
#   Bad structure: 0
#   Empty final responses: 0
#   With explicit tool_calls: 4552 (50.6%)
#   Without explicit tool_calls: 4448 (49.4%)
#
# Top role sequences (up to 5):
#   ('system', 'user', 'assistant', 'tool', 'assistant') -> 4552
#   ('system', 'user', 'assistant') -> 4448
#
# CANCER TYPE DISTRIBUTION:
#   pubmed_brain_tumour              1788  ########
#   pubmed_bone_cancer               1788  ########
#   pubmed_prostate_cancer           1787  ########
#   pubmed_lung_cancer               1787  ########
#   pubmed_colon_cancer              1787  ########
#   pubmed_ovarian_cancer            1787  ########
#   pubmed_skin_cancer               1787  ########
#   pubmed_breast_cancer             1787  ########
#   pubmed_kidney_cancer             1721  ########
#   pubmed_gastric_cancer            1694  ########
#   cancerguide_treatment_reasoning  1580  #######
#   TOTAL                           19293
#
# Dataset validated and ready for training

# %% [markdown]
# ## 4. Load Model & Tokenizer (4-bit)

# %%
from unsloth import FastLanguageModel
import torch

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=BASE_LLM,
    max_seq_length=MAX_SEQ_LENGTH,
    load_in_4bit=True
)

# ── CRITICAL: Override Unsloth's forced "eager" attention with Flash Attention 2 ──
# Unsloth forces attn_implementation="eager" for Gemma 3 (llama.py:2396 pops
# our kwarg, line 2427 passes "eager"). With "eager", Gemma3Attention.forward
# dispatches via ALL_ATTENTION_FUNCTIONS to eager_attention_forward which uses
# torch.matmul for Q@K^T — full O(n²) materialized attention. On a 27B model
# at seq_len 4096, this is the #1 reason training takes 182 hours instead of ~80.
#
# Gemma 3 uses the unified attention class (no separate SdpaAttention/FlashAttention
# subclasses). The dispatch is purely via config._attn_implementation at runtime.
# We override it AFTER Unsloth loads the model so flash_attention_forward runs instead.
#
# Requirements met:
#   - flash_attn 2.7.4 installed and working on sm_120 (Blackwell)
#   - GQA (32 query, 16 KV heads) — FA2 supports natively
#   - No softcap (attn_logit_softcapping=None in Gemma 3)
#   - sliding_window=1024 — FA2 handles via transformers wrapper
old_attn = getattr(model.config, "_attn_implementation", "unknown")
model.config._attn_implementation = "flash_attention_2"
print(f"  Attention override: {old_attn} -> flash_attention_2")

# Gemma tokenizer typically has pad_token already set (token id 0).
# Ensure it's configured; fall back to eos if missing.
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
    print(f"  Set pad_token = eos_token ({tokenizer.eos_token!r}, id={tokenizer.eos_token_id})")
else:
    print(f"  pad_token = {tokenizer.pad_token!r} (id={tokenizer.pad_token_id})")

model.config.pad_token_id = tokenizer.pad_token_id
if hasattr(model, "generation_config"):
    model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Model loaded: {BASE_LLM}")
print(f"  Precision: 4-bit QLoRA (pre-quantized NF4)")
print(f"  Max sequence length: {MAX_SEQ_LENGTH}")
print(f"  Vocab size: {len(tokenizer)}")
print(f"  GPU allocated: {torch.cuda.memory_allocated()/1e9:.1f} GB")
# Out:
# ==((====))==  Unsloth 2026.5.7: Fast Gemma3 patching. Transformers: 5.10.0.dev0.
#    \\   /|    NVIDIA GB10. Num GPUs = 1. Max memory: 121.689 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0a0+b558c986e8.nv25.11. CUDA: 12.1. CUDA Toolkit: 13.0. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33+aa7bc36.d20260302. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/808 [00:00<?, ?it/s]
#   Attention override: flash_attention_2 -> flash_attention_2
#   pad_token = '<pad>' (id=0)
# Model loaded: unsloth/medgemma-27b-text-it-unsloth-bnb-4bit
#   Precision: 4-bit QLoRA (pre-quantized NF4)
#   Max sequence length: 16384
#   Vocab size: 262145
#   GPU allocated: 16.6 GB

# %% [markdown]
# ## 5. Format Dataset for Chat Template
#
# Map ShareGPT roles to Gemma 3 chat template roles, apply the tokenizer's native chat template, then manual sequence packing for 100% token utilization.
#
# **Gemma role mapping:** `system` → `system`, `human` → `user`, `gpt` → `model`
#
# **Note:** The training data contains `<think>` reasoning blocks in the GPT responses. These are treated as regular content — MedGemma will learn to produce structured reasoning in this format during fine-tuning.

# %%
from datasets import Dataset as HFDataset
from tqdm.auto import tqdm
import json

# Fallback mapping if a non-tool ShareGPT row appears.
ROLE_MAP = {"system": "system", "human": "user", "gpt": "model"}

def _format_messages_for_gemma(messages):
    gemma_msgs = []
    # If the first message is system, keep its role as system
    has_system = messages and messages[0].get("role") == "system"
    if has_system:
        gemma_msgs.append({
            "role": "system",
            "content": messages[0].get("content", "").strip()
        })
        messages = messages[1:]
        
    for m in messages:
        role = m.get("role")
        content = m.get("content") or ""
        tool_calls = m.get("tool_calls")
        
        # Normalize role
        if role == "assistant":
            role = "model"
            
        if role == "user":
            gemma_msgs.append({"role": "user", "content": content})
        elif role == "model":
            if tool_calls:
                # Format tool call using Gemma 3's native <call:tool_name>...</call:tool_name> structure
                tc = tool_calls[0]
                fn = tc.get("function", {})
                tool_name = fn.get("name") or tc.get("name") or m.get("name") or "tool"
                args = fn.get("arguments", "{}")
                gemma_msgs.append({
                    "role": "model",
                    "content": f"<call:{tool_name}>{args}</call:{tool_name}>"
                })
            else:
                gemma_msgs.append({"role": "model", "content": content})
        elif role == "tool":
            # Map tool output using Gemma 3's native <response:tool_name>...</response:tool_name> structure
            tool_name = m.get("name") or "tool"
            gemma_msgs.append({
                "role": "user",
                "content": f"<response:{tool_name}>\n{content}\n</response:{tool_name}>"
            })
    return gemma_msgs

chat_conversations = []
for i, example in enumerate(tqdm(dataset, desc="Formatting and Mapping roles")):
    if "messages" in example:
        messages = example["messages"]
    else:
        messages = [
            {"role": ROLE_MAP[turn["from"]], "content": turn["value"]}
            for turn in example["conversations"]
        ]
    chat_conversations.append(_format_messages_for_gemma(messages))

# Gemma 2 chat template
print("Applying chat template...")
formatted_texts = tokenizer.apply_chat_template(
    chat_conversations,
    tokenize=False,
)

# ── Manual sequence packing ──
eos_id = tokenizer.eos_token_id
num_conversations = 0
all_ids = []

for text in tqdm(formatted_texts, desc="Tokenizing & packing"):
    if not text:
        continue
    ids = tokenizer(text, add_special_tokens=False, truncation=False)["input_ids"]
    all_ids.extend(ids)
    all_ids.append(eos_id)
    num_conversations += 1

total_tokens = len(all_ids)
num_chunks = total_tokens // MAX_SEQ_LENGTH
all_ids = all_ids[:num_chunks * MAX_SEQ_LENGTH]
chunks = [all_ids[i * MAX_SEQ_LENGTH:(i + 1) * MAX_SEQ_LENGTH] for i in range(num_chunks)]

packed_texts = tokenizer.batch_decode(chunks, skip_special_tokens=False)
dataset = HFDataset.from_dict({"text": packed_texts})
dataset = dataset.shuffle(seed=42)

wasted = total_tokens - (num_chunks * MAX_SEQ_LENGTH)
print(f"Dataset packed: {num_conversations} conversations -> {num_chunks} chunks of {MAX_SEQ_LENGTH} tokens")
print(f"  Total tokens: {total_tokens:,}  |  Wasted (tail): {wasted:,} ({100*wasted/total_tokens:.1f}%)")
print(f"  Token utilization: ~100% (no padding)")
print(f"\n--- Sample packed text (first 500 chars) ---")
print(dataset[0]["text"][:500])
# Out:
# Formatting and Mapping roles:   0%|          | 0/9000 [00:00<?, ?it/s]
# Applying chat template...
# Tokenizing & packing:   0%|          | 0/9000 [00:00<?, ?it/s]
# Dataset packed: 9000 conversations -> 1715 chunks of 16384 tokens
#   Total tokens: 28,105,181  |  Wasted (tail): 6,621 (0.0%)
#   Token utilization: ~100% (no padding)
#
# --- Sample packed text (first 500 chars) ---
#  For biomedical literature, oncology, clinical evidence, trial, biomarker, mechanism, treatment, guideline, or PubMed-style questions, call `oncology_guidelines_db` before answering.
# - When you call `oncology_guidelines_db`, do not answer in the same assistant turn. Wait for the tool result, then synthesize the answer from the returned evidence.
# - Do not invent PMIDs, trial names, statistics, guideline statements, or article details. If the tool result is incomplete, say what remains uncertain.

# %% [markdown]
# ## 6. Add LoRA Adapters

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=LORA_R,
    target_modules=LORA_TARGET_MODULES,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=3407,
    max_seq_length=MAX_SEQ_LENGTH,
)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(f"LoRA adapters added (r={LORA_R}, alpha={LORA_ALPHA})")
print(f"  Trainable: {trainable:,} / {total:,} params ({100*trainable/total:.2f}%)")
print(f"  Target modules: {LORA_TARGET_MODULES}")
# Out:
# /usr/local/lib/python3.12/dist-packages/awq/__init__.py:21: DeprecationWarning:
# I have left this message as the final dev message to help you transition.
#
# Important Notice:
# - AutoAWQ is officially deprecated and will no longer be maintained.
# - The last tested configuration used Torch 2.6.0 and Transformers 4.51.3.
# - If future versions of Transformers break AutoAWQ compatibility, please report the issue to the Transformers project.
#
# Alternative:
# - AutoAWQ has been adopted by the vLLM Project: https://github.com/vllm-project/llm-compressor
#
# For further inquiries, feel free to reach out:
# - X: https://x.com/casper_hansen_
# - LinkedIn: https://www.linkedin.com/in/casper-hansen-804005170/
#
#   warnings.warn(_FINAL_DEV_MESSAGE, category=DeprecationWarning, stacklevel=1)
# <pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# <pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>
# <pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# <pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>
# fatal: detected dubious ownership in repository at '/workspace/training/pubmed'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /workspace/training/pubmed
# <pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>
# INFO
#
# ┌─────────────┐    ┌────────────────────────┐    ┌────────────┐    ┌─────────┐
# │ GPT-QModel  │ -> │ ▓▓▓▓▓▓▓▓▓▓▓▓ 16bit     │ -> │ ▒▒▒▒ 8bit  │ -> │ ░░ 4bit │
# └─────────────┘    └────────────────────────┘    └────────────┘    └─────────┘
# GPT-QModel   : 7.0.0
# Transformers : 5.10.0.dev0
# Torch        : 2.10.0a0+b558c986e8.nv25.11
# Triton       : 3.4.0+gitc5d671f9
# <pre style="margin:0; white-space:pre; font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;"></pre>
# LoRA adapters added (r=32, alpha=32)
#   Trainable: 227,033,088 / 14,610,262,784 params (1.55%)
#   Target modules: ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj']

# %% [markdown]
# ## 7. Trainer Setup

# %%
import torch
from transformers import DataCollatorForLanguageModeling
from trl import SFTTrainer, SFTConfig

# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║  TRL 0.24.0 Backwards Compatibility Patch: Inline DataCollator              ║
# ║                                                                              ║
# ║  TRL v0.24.0 has removed/deprecated the imports interface for                ║
# ║  DataCollatorForCompletionOnlyLM in favor of native tokenizers.              ║
# ║  This inline class ensures compatibility and runs flawlessly across both    ║
# ║  Docker system scopes and unified host pyenvironments.                       ║
# ╚══════════════════════════════════════════════════════════════════════════════╝

class CustomCompletionCollator(DataCollatorForLanguageModeling):
    def __init__(self, response_template, tokenizer, *args, **kwargs):
        # DataCollatorForLanguageModeling expects `tokenizer` as its first positional arg.
        # It does not take a custom `pad_token_id` kwarg, it uses the tokenizer's instead.
        super().__init__(tokenizer=tokenizer, *args, **kwargs)
        self.response_template = response_template
        self.tokenizer = tokenizer
        
        if isinstance(self.response_template, str):
            self.response_token_ids = self.tokenizer.encode(self.response_template, add_special_tokens=False)
        else:
            self.response_token_ids = self.response_template

    def torch_call(self, examples):
        batch = super().torch_call(examples)
        
        # Mask all tokens preceding the end of the response template inside the labels tensor
        for i in range(len(examples)):
            response_start_idx = None
            
            # Line scan labels to locate response template start
            for idx in range(len(batch["labels"][i]) - len(self.response_token_ids) + 1):
                if batch["labels"][i][idx : idx + len(self.response_token_ids)].tolist() == self.response_token_ids:
                    response_start_idx = idx
                    break
                    
            if response_start_idx is not None:
                response_end_idx = response_start_idx + len(self.response_token_ids)
                # Apply loss target masking of -100 labels to preceding index ranges
                batch["labels"][i][:response_end_idx] = -100
            else:
                # Safe-fail: Map entire example sequence to loss mask if template is not matched
                batch["labels"][i][:] = -100
                
        return batch

# ── Improvement C: SFT Token-Level Loss Masking ──────────────────────────
response_template = "<start_of_turn>model\n"

collator = CustomCompletionCollator(
    response_template=response_template,
    tokenizer=tokenizer,
    mlm=False,
)

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    data_collator=collator, # Assign inline CompletionOnly collator
    args=SFTConfig(
        dataset_text_field="text",
        max_seq_length=MAX_SEQ_LENGTH,
        packing=False, # Must be False for collator to mask appropriately
        per_device_train_batch_size=BATCH_SIZE,
        gradient_accumulation_steps=GRAD_ACCUM,
        warmup_steps=5,
        num_train_epochs=TARGET_EPOCHS,
        learning_rate=LEARNING_RATE,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir=OUTPUT_DIR_ADAPTERS,
        save_strategy="steps",
        save_steps=100,
        save_total_limit=3,
        report_to="none",
        dataset_num_proc=1,
    ),
)

effective_batch_size = BATCH_SIZE * GRAD_ACCUM
num_steps = (len(dataset) * TARGET_EPOCHS + effective_batch_size - 1) // effective_batch_size
print(f"Trainer configured (PubMed Oncology MedGemma 27B 4-bit QLoRA — pre-packed)")
print(f"  Effective batch size: {BATCH_SIZE} x {GRAD_ACCUM} = {effective_batch_size}")
print(f"  Epochs: {TARGET_EPOCHS}  |  Steps: ~{num_steps}")
print(f"  LR: {LEARNING_RATE}")
print(f"  Loss Masking: Active via CustomCompletionCollator (template: {response_template!r})")
print(f"  Packing: manual (pre-packed, each example = {MAX_SEQ_LENGTH} tokens, zero padding)")
print(f"  Precision: {'bf16' if torch.cuda.is_bf16_supported() else 'fp16'}")
print(f"  Dataset: {len(dataset)} packed chunks")
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=1):   0%|          | 0/1715 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/multiprocess/popen_fork.py:66: DeprecationWarning: This process (pid=579) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Trainer configured (PubMed Oncology MedGemma 27B 4-bit QLoRA — pre-packed)
#   Effective batch size: 2 x 4 = 8
#   Epochs: 1  |  Steps: ~215
#   LR: 0.0002
#   Loss Masking: Active via CustomCompletionCollator (template: '<start_of_turn>model\n')
#   Packing: manual (pre-packed, each example = 16384 tokens, zero padding)
#   Precision: bf16
#   Dataset: 1715 packed chunks

# %% [markdown]
# ## 8. Train

# %%
from transformers.trainer_utils import get_last_checkpoint

last_ckpt = get_last_checkpoint(trainer.args.output_dir)
if last_ckpt is not None:
    print(f"Resuming from checkpoint: {last_ckpt}")
    result = trainer.train(resume_from_checkpoint=True)
else:
    print("No previous checkpoint found — starting fresh.")
    result = trainer.train()

print(f"\n✓ Training complete!")
print(f"  Final loss:     {result.training_loss:.4f}")
print(f"  Total steps:    {result.global_step}")
print(f"  Training time:  {result.metrics.get('train_runtime', 0) / 60:.1f} minutes")
# Out:
# No previous checkpoint found — starting fresh.
# [transformers] ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,715 | Num Epochs = 1 | Total steps = 215
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 227,033,088 of 27,236,035,328 (0.83% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
# Unsloth: Double buffering enabled (parallel H2D + compute) for backward pass.
#     <div>
#
#       <progress value='215' max='215' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [215/215 24:55:14, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>7.318943</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.358215</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.132417</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.549130</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.639441</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.230318</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.793527</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.543701</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.092892</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.778145</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.216189</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.867872</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.385444</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.971452</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.694416</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.539763</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.455072</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.374767</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.297984</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.273854</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.189109</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.207294</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.127399</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.091856</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.096462</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.059078</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.059760</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.991944</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.980630</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.990736</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.943685</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.939601</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.958783</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.913109</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.900453</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.896631</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.869575</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.884963</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.871034</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.878592</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.858615</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.873432</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.814174</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.829315</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.840820</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.838983</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.822421</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.833626</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.784990</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.801609</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.770770</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.808773</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.789975</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.780818</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.780162</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.754946</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.792953</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.755244</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.783338</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.775000</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.776553</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.741499</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.748199</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.765292</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.745576</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.713815</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.753627</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.731911</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.726515</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.726040</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.759322</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.746296</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.713641</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.719742</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.709824</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.715420</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.746424</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.735193</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.745600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.723061</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.743033</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.723790</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.751744</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.708468</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.721271</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.704253</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.684466</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.723577</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.685224</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.693388</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.670089</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.673004</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.699700</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.694686</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.712435</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.667712</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.663769</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.701066</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.683755</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.663619</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.669069</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.700340</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.651599</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.688654</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.659716</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.679529</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.699293</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.667810</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.701007</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.668528</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.678418</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.687467</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.651032</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.685181</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.664211</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.680209</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.683709</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.675860</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.638251</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.646674</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.694284</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.664425</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.672948</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.705449</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.679160</td>
#     </tr>
#     <tr>
#       <td>126
# [transformers] Unsloth: Restored added_tokens_decoder metadata in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/train/checkpoint-100/tokenizer_config.json.
# [transformers] Unsloth: Preserved sentencepiece asset `tokenizer.model` in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/train/checkpoint-100.
# [transformers] Unsloth: Restored added_tokens_decoder metadata in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/train/checkpoint-200/tokenizer_config.json.
# [transformers] Unsloth: Preserved sentencepiece asset `tokenizer.model` in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/train/checkpoint-200.
# [transformers] Unsloth: Restored added_tokens_decoder metadata in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/train/checkpoint-215/tokenizer_config.json.
# [transformers] Unsloth: Preserved sentencepiece asset `tokenizer.model` in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/train/checkpoint-215.
# ✓ Training complete!
#   Final loss:     1.0030
#   Total steps:    215
#   Training time:  1502.4 minutes

# %% [markdown]
# ## 9. Save LoRA Adapters
#
# Save the trained LoRA adapters and system prompts. The DPO notebook (Phase 2) expects the LoRA at this path.

# %%
import json
from pathlib import Path

Path(LORA_OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

print(f"Saving LoRA adapters to {LORA_OUTPUT_DIR}...")
model.save_pretrained(LORA_OUTPUT_DIR)
tokenizer.save_pretrained(LORA_OUTPUT_DIR)

# Save system prompts alongside adapters for inference use
prompts_path = f"{LORA_OUTPUT_DIR}/oncologist_system_prompts.json"
with open(prompts_path, "w") as f:
    json.dump(system_prompts_by_cancer, f, indent=2)

print(f"\nLoRA adapters saved!")
print(f"  Adapters:       {LORA_OUTPUT_DIR}")
print(f"  System prompts: {prompts_path} ({len(system_prompts_by_cancer)} cancer types)")
print(f"  DPO notebook expects LoRA at: {{PROJECT_ROOT}}/output/v3/{{MODEL_NAME_BASE}}/lora_adapters")

for p in sorted(Path(LORA_OUTPUT_DIR).iterdir()):
    size_mb = p.stat().st_size / 1024 / 1024
    print(f"  {p.name:40s} {size_mb:>8.1f} MB")
# Out:
# Saving LoRA adapters to /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters...
# [transformers] Unsloth: Restored added_tokens_decoder metadata in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters/tokenizer_config.json.
# [transformers] Unsloth: Preserved sentencepiece asset `tokenizer.model` in /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters.
# LoRA adapters saved!
#   Adapters:       /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters
#   System prompts: /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters/oncologist_system_prompts.json (11 cancer types)
#   DPO notebook expects LoRA at: {PROJECT_ROOT}/output/v3/{MODEL_NAME_BASE}/lora_adapters
#   README.md                                     0.0 MB
#   adapter_config.json                           0.0 MB
#   adapter_model.safetensors                   866.2 MB
#   chat_template.jinja                           0.0 MB
#   oncologist_system_prompts.json                0.0 MB
#   tokenizer.json                               31.8 MB
#   tokenizer.model                               4.5 MB
#   tokenizer_config.json                         1.1 MB

# %% [markdown]
# ## 10. Test Inference
#
# Smoke test with oncology questions across different cancer types. The training data includes `<think>` reasoning blocks, so the model may produce them in responses.

# %%
import warnings, logging, json
from transformers import TextStreamer

# Suppress transformers deprecation warning bug (msg % FutureWarning formatting error)
warnings.filterwarnings("ignore", category=FutureWarning)
logging.getLogger("transformers.modeling_attn_mask_utils").setLevel(logging.ERROR)

# Load model from saved adapters if not already in memory
if "model" not in dir() or model is None:
    from unsloth import FastLanguageModel
    print(f"Model not in memory — loading from saved adapters: {LORA_OUTPUT_DIR}")
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=LORA_OUTPUT_DIR,
        max_seq_length=MAX_SEQ_LENGTH,
        load_in_4bit=True,
    )
    model.config._attn_implementation = "flash_attention_2"

if "system_prompts_by_cancer" not in dir() or not system_prompts_by_cancer:
    with open(f"{LORA_OUTPUT_DIR}/oncologist_system_prompts.json") as f:
        system_prompts_by_cancer = json.load(f)

FastLanguageModel.for_inference(model)

test_cancers = list(system_prompts_by_cancer.keys())[:3]

print(f"INFERENCE TEST — {len(test_cancers)} CANCER TYPES\n")

for cancer_type in test_cancers:
    system_prompt = system_prompts_by_cancer[cancer_type]

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": TEST_PROMPT},
    ]

    # Gemma 3 chat template — no enable_thinking parameter
    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )
    inputs = tokenizer(text, return_tensors="pt").to(model.device)

    print(f"{'='*60}")
    print(f"  CANCER TYPE: {cancer_type.upper()}")
    print(f"  Q: {TEST_PROMPT}")
    print(f"  A: ", end="")

    outputs = model.generate(
        **inputs,
        max_new_tokens=2048,
        temperature=0.7,
        top_p=0.8,
        do_sample=True,
        streamer=TextStreamer(tokenizer, skip_prompt=True),
    )
    print()

del inputs, outputs
# Out:
# [transformers] Both `max_new_tokens` (=2048) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFERENCE TEST — 3 CANCER TYPES
#
# ============================================================
#   CANCER TYPE: CANCERGUIDE_TREATMENT_REASONING
#   Q: A 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer has progressed after platinum-based chemotherapy and a PARP inhibitor. What are the next treatment options?
#   A: <think>
# Okay, let me approach this systematically as a clinical oncologist. The patient is a 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer (HGSOC) who has progressed after standard first-line therapy: platinum-based chemotherapy and PARP inhibitor maintenance.
#
# First, I need to confirm the key clinical details:
# - BRCA1 mutation confirmed (critical for PARP inhibitor response)
# - HGSOC histology (most common ovarian cancer subtype)
# - Progression after platinum + PARP inhibitor (likely maintenance phase)
# - Age 58 (generally fit for further treatment)
#
# The question asks for next treatment options, so I should structure my response around evidence-based pathways while acknowledging limitations.
#
# Hmm... the standard sequence for BRCA-mutated ovarian cancer is platinum-based chemo followed by PARP inhibitor maintenance. Since she's progressed on both, we're now in the platinum-resistant setting. I recall the SOLO-1 trial showed olaparib maintenance improved PFS in BRCA-mutated patients after response to platinum, but progression still occurs.
#
# Let me consider the options sequentially:
# 1. Re-challenge with platinum? The evidence here is mixed. Some studies like GOG-3006 suggest platinum rechallenge can be effective in 15-20% of cases, but response rates are lower after PARP inhibitor exposure. The risk of cumulative nephrotoxicity and myelosuppression is significant at age 58.
#
# 2. Alternative PARP inhibitors? Since she progressed on one PARP inhibitor (likely olaparib or niraparib), switching to another might be an option. The ARIEL3 trial showed niraparib could be used after platinum resistance, but the benefit in BRCA-mutated patients specifically isn't as robust as in HRD-positive. Still, it's a reasonable consideration if she tolerated the first PARP inhibitor well.
#
# 3. Non-PARP targeted options:
#    - Bevacizumab? SOLO-1 showed bevacizumab maintenance improved PFS after platinum in BRCA-mutated patients, but it's not standard for progression. However, some retrospective data suggest it may have activity in platinum-resistant disease.
#    - Immunotherapy? The KEYNOTE-100 trial showed pembrolizumab benefit in PD-L1-positive ovarian cancer, but HGSOC rarely expresses PD-L1. Still worth considering if biomarker testing is available.
#    - MEK inhibitors? The NRG-GY018 trial showed trametinib + dabrafenib in BRAF-mutated ovarian cancer, but this patient's tumor isn't specified as BRAF-mutated.
#    - Topotecan? A single-agent chemo option, but response rates are low (around 10-15%) and duration is short.
#
# 4. Clinical trials: This is crucial. Given the limited options, enrolling in a trial would be ideal. I should mention specific trials like:
#    - PARP inhibitor combinations (e.g., with bevacizumab)
#    - Novel targets like ATR inhibitors
#    - Antibody-drug conjugates (e.g., mirvetuximab soravtansine for FRα-positive tumors)
#
# Important caveats to include:
# - Must confirm BRCA status is germline vs somatic (germline BRCA is more actionable)
# - Need to assess platinum resistance mechanism (e.g., via ctDNA for HRD status)
# - Performance status is critical - at 58 she's likely ECOG 0-1, but should verify
# - Toxicity profiles matter: avoid nephrotoxic agents if she has renal impairment
#
# I should emphasize that platinum rechallenge has the strongest evidence among non-trial options, but the response rate is modest. Alternative PARP inhibitors are reasonable if she tolerated the first one well. For immunotherapy, only consider if PD-L1 positive. Clinical trials should be prioritized.
#
# Also need to mention supportive care: pain management, ascites control, nutritional support - especially since she's progressed.
#
# Must avoid overpromising - no curative options exist at this stage, so focus on extending life with manageable toxicity. The response rates for most options are in the 10-30% range, so setting realistic expectations is key.
#
# Finally, I'll structure the answer as:
# 1. Standard options with evidence level
# 2. Emerging options
# 3. Clinical trial considerations
# 4. Essential prerequisites (biomarker testing, performance status)
# 5. Caveats about evidence limitations
# </think>
#
# ### Evidence-Based Treatment Options for Platinum-Resistant BRCA1-Mutated HGSOC
#
# As a clinical oncologist, I'll address this case systematically, adhering to current guidelines (NCCN, ESMO) and evidence hierarchy. The patient is a 58-year-old woman with **BRCA1-mutated high-grade serous ovarian cancer (HGSOC)** who has progressed after **platinum-based chemotherapy** and **PARP inhibitor (PARPi) maintenance therapy**. This represents a critical treatment-resistant scenario requiring careful consideration of efficacy, toxicity, and quality of life.
#
# ---
#
# #### **I. Core Principles & Pre-Treatment Assessment**
#
# Before discussing options, **essential prerequisites** must be confirmed:
# 1. **Confirm BRCA1 status**: Verify if the mutation is germline (via blood/saliva) or somatic (via tumor tissue). *Germline BRCA1 is actionable; somatic requires re-testing for validity*.
# 2. **Assess platinum resistance mechanism**:
#    - **HRD status**: Is the tumor homologous recombination deficient (HRD)? While BRCA1 mutation implies HRD, confirm via genomic testing (e.g., Myriad MyChoice®).
#    - **ctDNA analysis**: If available, assess for *BRCA1* reversion mutations or other resistance mechanisms (e.g., *TP53* mutations).
# 3. **Performance status (PS)**: ECOG/Karnofsky score is critical. At 58, she is likely ECOG 0-1, but progression may have impacted PS.
# 4. **Toxicity review**: Document prior PARPi exposure (e.g., olaparib, niraparib), platinum-related toxicities (e.g., neuropathy, nephrotoxicity), and current comorbidities (e.g., renal function, cytopenias).
#
# ---
#
# #### **II. Evidence-Based Treatment Options**
#
# Based on randomized trial data and guidelines, options are stratified by evidence strength:
#
# ##### **A. Platinum Rechallenge (Level 1 Evidence)**
# - **Rationale**: ~15-20% of patients with platinum-resistant ovarian cancer respond to platinum rechallenge (GOG-3006 trial). BRCA1-mutated tumors may retain HRD, potentially restoring platinum sensitivity.
# - **Evidence**:
#   - **GOG-3006**: In *BRCA*-mutated patients, platinum rechallenge ORR was 19% (95% CI: 10-29%) with median PFS of 4.1 months. *However, this included patients who received PARPi maintenance*.
#   - **SOLO-1**: In *BRCA*-mutated patients progressing on PARPi, platinum rechallenge ORR was 15% (vs. 10% in HRD-positive non-*BRCA*).
# - **Pros**: Highest ORR among non-trial options; may provide rapid symptom control.
# - **Cons**: Limited durability; risk of cumulative platinum toxicity (nephrotoxicity, myelosuppression); ORR reduced after prior PARPi exposure.
# - **Guideline recommendation**: NCCN lists platinum rechallenge as a "category 1" option for platinum-resistant ovarian cancer (NCCN v.3.2024), but emphasizes individual risk-benefit assessment.
#
# ##### **B. Alternative PARP Inhibitors (Level 2 Evidence)**
# - **Rationale**: Cross-resistance between PARPis exists, but switching may benefit patients with specific resistance mechanisms.
# - **Evidence**:
#   - **ARIEL3**: Niraparib (vs. placebo) in platinum-resistant ovarian cancer showed ORR of 24% in *BRCA*-mutated patients (vs. 12% in HRD-positive non-*BRCA*). *However, this trial excluded patients who received prior PARPi*.
#   - **PRIMA/ENGAGE**: Olaparib (vs. placebo) in *BRCA*-mutated advanced ovarian cancer showed ORR of 24% in platinum-resistant patients.
# - **Pros**: May overcome resistance if prior PARPi was suboptimal; oral administration.
# - **Cons**: Lower ORR after prior PARPi exposure (ORR ~10-15% in real-world data); risk of overlapping toxicities (fatigue, anemia, nausea).
# - **Guideline recommendation**: NCCN suggests considering alternative PARPi if prior PARPi was well-tolerated but ineffective (NCCN v.3.2024).
#
# ##### **C. Bevacizumab Monotherapy (Level 2 Evidence)**
# - **Rationale**: Anti-angiogenic activity may target residual tumor vasculature.
# - **Evidence**:
#   - **SOLO-1**: Bevacizumab maintenance after platinum in *BRCA*-mutated patients improved PFS (HR 0.53; 95% CI: 0.38-0.74) but did not show OS benefit. *No data on progression after PARPi*.
#   - Retrospective studies (e.g., GOG-0218) suggest be
# [transformers] Both `max_new_tokens` (=2048) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ============================================================
#   CANCER TYPE: PUBMED_PROSTATE_CANCER
#   Q: A 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer has progressed after platinum-based chemotherapy and a PARP inhibitor. What are the next treatment options?
#   A: <think>
# Okay, let me approach this systematically as a clinical oncologist. The user presents a complex case of a 58-year-old woman with advanced ovarian cancer who has progressed after platinum-based chemotherapy and PARP inhibitor treatment.
#
# First, I need to verify the key details: she has BRCA1-mutated high-grade serous ovarian cancer (HGSOC), which is crucial because BRCA status dictates treatment options. She's progressed after two lines of therapy - platinum chemo and a PARP inhibitor. The question asks for next treatment options.
#
# Hmm, this is a classic scenario where we must consider the molecular profile first. BRCA1 mutation means she should have responded to platinum initially (which is standard for HGSOC), but now she's progressed. The PARP inhibitor failure is particularly important because it suggests either acquired resistance or perhaps suboptimal initial response.
#
# I recall the SOLO-1 trial showed olaparib maintenance after platinum response in BRCA-mutated patients improved PFS to 34 months vs 14.1 months with placebo. But here, she's already progressed on a PARP inhibitor - that's different. The standard for progression after PARP inhibitors in this setting isn't as well-defined.
#
# Let me think through the options:
# 1) Rechallenge with platinum: But she's progressed after platinum, so retreatment is generally not recommended. The GOG-218 trial showed no benefit for platinum retreatment in recurrent ovarian cancer. However, BRCA status might modify this - some data suggest BRCA-mutated tumors retain sensitivity longer. Still, the evidence is weak.
#
# 2) Alternative PARP inhibitors: If she failed one PARP inhibitor (say olaparib), could we switch to another? The ARIEL3 trial showed niraparib maintenance after platinum response improved PFS, but it didn't specifically address progression after prior PARP inhibitors. There's limited data on sequential PARP inhibitors - the NOVA trial used niraparib after platinum but not after PARP inhibitor failure.
#
# 3) Immunotherapy: For ovarian cancer, the KEYNOTE-100 trial showed pembrolizumab + bevacizumab improved OS in PD-L1+ tumors, but only for maintenance. For progression after PARP inhibitors? The DUBLIN trial showed no benefit for atezolizumab in platinum-resistant ovarian cancer. BRCA mutation might theoretically increase immunotherapy response, but evidence is lacking.
#
# 4) Clinical trials: This is probably the best option. Given she's progressed after two lines, she's a candidate for trials testing novel combinations. I should mention specific trials like those with antibody-drug conjugates (e.g., mirvetuximab for folate receptor-positive) or bispecific antibodies.
#
# Important considerations:
# - Her BRCA1 status is key - it affects platinum sensitivity and PARP inhibitor efficacy.
# - Progression after PARP inhibitor suggests resistance mechanisms like reversion mutations in BRCA.
# - Must consider her performance status - the question doesn't specify, but that's critical for treatment selection.
# - No mention of residual disease or biomarkers beyond BRCA.
#
# I need to be careful not to overstate evidence. For platinum rechallenge, I should cite the GOG-218 data but note BRCA status might modify outcomes. For immunotherapy, emphasize the lack of robust data in this specific scenario. Clinical trials should be highlighted as the most evidence-based approach.
#
# Also must address limitations: no details on prior treatments (was the PARP inhibitor maintenance or treatment?), performance status, or current symptoms. These would heavily influence real-world decisions.
#
# The answer structure should follow:
# - Biological context (BRCA repair deficiency)
# - Evidence for each option (with caveats)
# - Clinical recommendations
# - Limitations of current knowledge
# </think>
#
# ### Comprehensive Analysis: Next Treatment Options for BRCA1-Mutated Ovarian Cancer Progression After Platinum and PARP Inhibitor Therapy
#
# **Biological Context First**
# BRCA1-mutated high-grade serous ovarian cancer (HGSOC) is driven by homologous recombination deficiency (HRD), making it exquisitely sensitive to platinum-based chemotherapy (due to impaired DNA repair) and PARP inhibitors (which exploit synthetic lethality in HRD). However, progression after platinum and PARP inhibitor therapy indicates the development of resistance mechanisms. Key resistance pathways include:
# - **Reversion mutations** in *BRCA1* (e.g., loss of exon 20)
# - **Upregulation of alternative DNA repair pathways** (e.g., *BRCA2*, *RAD51*, *PALB2*)
# - **Loss of HRD signature** (e.g., *BRCA1* promoter methylation)
# - **Tumor heterogeneity** with non-HRD clones
# - **Pharmacodynamic resistance** (e.g., increased efflux pumps for PARP inhibitors)
#
# **Evidence-Based Treatment Options**
# *Note: All recommendations assume adequate performance status (ECOG 0-1) and absence of contraindications. Specific trial eligibility requires molecular profiling of the current tumor.*
#
# ---
#
# #### **1. Platinum Rechallenge**
# - **Rationale**: BRCA1-mutated tumors typically retain sensitivity to platinum longer than HRD-negative tumors due to persistent HRD. While standard for *de novo* HGSOC, rechallenge after progression is controversial.
# - **Evidence**:
#   - **GOG-218 Trial** (J Clin Oncol 2018): Platinum retreatment showed no OS benefit in recurrent ovarian cancer (HR 0.98; 95% CI 0.77–1.25), but subgroup analysis suggested potential benefit in *BRCA*-mutated patients (HR 0.72; 95% CI 0.53–0.98).
#   - **SOLO-1 Trial** (Lancet 2018): BRCA-mutated patients receiving olaparib maintenance had 34 months PFS vs. 14.1 months with placebo. Progression on PARP inhibitors does not preclude platinum sensitivity.
# - **Clinical Implication**:
#   - **Recommended**: Consider platinum rechallenge *only if* prior platinum was given >6 months ago and the tumor has regressed clinically/radiologically.
#   - **Caveat**: Response rates are lower than initial treatment (20–40% vs. 80–90%). Toxicity (neuropathy, myelosuppression) may be limiting.
#   - **Guideline Status**: NCCN (v.3.2024) lists platinum retreatment as "Category 2A" for recurrent HGSOC, but *BRCA* status is not specified as a modifier.
#
# ---
#
# #### **2. Alternative PARP Inhibitors**
# - **Rationale**: Resistance to one PARP inhibitor may not extend to others due to differences in pharmacokinetics, tumor penetration, or resistance mechanisms.
# - **Evidence**:
#   - **ARIEL3 Trial** (Gynecol Oncol 2021): Niraparib maintenance after platinum improved PFS in *BRCA*-mutated patients (HR 0.34; 95% CI 0.22–0.53), but *no data on progression after prior PARP inhibitors*.
#   - **NOVA Trial** (J Clin Oncol 2021): Niraparib maintenance after platinum showed PFS benefit (HR 0.57; 95% CI 0.42–0.77), but excluded patients with prior PARP inhibitor exposure.
# - **Clinical Implication**:
#   - **Consider**: Switching from olaparib (if previously used) to niraparib or rucaparib. However, **no prospective data support efficacy after PARP inhibitor failure**. Case reports suggest limited activity (e.g., 20% response rate with niraparib).
#   - **Limitation**: High risk of cross-resistance due to overlapping resistance mechanisms (e.g., *BRCA* reversion mutations).
#
# ---
#
# #### **3. Immunotherapy Combinations**
# - **Rationale**: BRCA1-mutated tumors have high tumor mutational burden (TMB) and PD-L1 expression, potentially increasing immunotherapy response.
# - **Evidence**:
#   - **KEYNOTE-100 Trial** (J Clin Oncol 2021): Pembrolizumab + bevacizumab improved OS in *BRCA*-mutated ovarian cancer (HR 0.60; 95% CI 0.43–0.83) *only as maintenance* after platinum.
#   - **DUBLIN Trial** (Lancet Oncol 2021): Atezolizumab + bevacizumab showed no benefit in platinum-resistant ovarian cancer (PFS HR 1.04; 95% CI 0.77–1.41).
# - **Clinical Implication**:
#   - **Not recommended as monotherapy**: Immunotherapy alone has minimal activity in ovarian cancer (ORR <5%).
#   - **Potential role**: Combination with platinum (e.g., pembrolizumab + carboplatin) *if* prior platinum was >6 months ago. However, **no data support this after PARP inhibitor failure**.
#   - **Caveat**: High risk of immune-related adverse events (irAEs) in elderly patients.
#
# ---
#
# #### **4. Targeted Therapy Beyond PARP**
# - **Rationale**: Explore resistance-overcoming pathways.
# - **Evidence**:
#   - **Antibody-drug conjugates
# [transformers] Both `max_new_tokens` (=2048) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ============================================================
#   CANCER TYPE: PUBMED_KIDNEY_CANCER
#   Q: A 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer has progressed after platinum-based chemotherapy and a PARP inhibitor. What are the next treatment options?
#   A: <think>
# Okay, let me approach this systematically as a clinical oncologist would. The user presents a complex case: a 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer (HGSOC) who has progressed after platinum-based chemotherapy and a PARP inhibitor.
#
# First, I need to unpack the clinical scenario. The patient has BRCA1-mutated HGSOC - that's crucial because it's a homologous recombination deficiency (HRD) tumor. She's already received platinum-based chemo and a PARP inhibitor (likely olaparib or niraparib based on FDA approvals), which is standard first-line maintenance after response to platinum. Now she's progressed, so we're in the relapsed/refractory setting.
#
# Hmm... the key question is about next treatment options. I should start by recalling the molecular biology: BRCA1 mutations cause defective homologous recombination repair, making these tumors exquisitely sensitive to PARP inhibitors. But resistance mechanisms exist - reversion mutations, bypass pathways like RAD51 upregulation, or even tumor evolution. The progression after PARPi suggests either true resistance or perhaps inadequate prior treatment (though the case says she had response).
#
# Let me think through the standard pathways. For BRCA-mutated ovarian cancer, PARP inhibitors are the cornerstone of maintenance therapy. After progression on PARPi, the options are limited but evolving. I recall the SOLO-2 trial showed olaparib benefit in platinum-sensitive recurrence, but this patient progressed after PARPi - so she's likely platinum-resistant now.
#
# Wait, I need to clarify the progression status. Is it platinum-sensitive or resistant recurrence? The case doesn't specify, but progression after PARPi often implies resistance. That changes everything. For platinum-resistant BRCA-mutated ovarian cancer, the options are even narrower.
#
# I should check recent guidelines. NCCN 2024 for ovarian cancer lists several possibilities:
# - Another PARP inhibitor if she progressed on one specific drug (like switching from olaparib to niraparib, though evidence is weak)
# - Clinical trials
# - Possibly bevacizumab combinations
# - Maybe platinum rechallenge if she had a good response initially
#
# But the evidence quality here is tricky. There are no phase III trials for second-line PARPi in this setting. Most data comes from small studies like the NOVA trial subgroup analysis or case reports. I must emphasize this uncertainty.
#
# Also, the patient's age and performance status matter. At 58, she's likely fit for clinical trials, but we don't have details on comorbidities. I should mention that toxicity profiles differ - another PARPi might cause similar side effects like myelosuppression.
#
# I recall the ARIEL3 trial showed niraparib benefit in maintenance, but progression on PARPi isn't the same as maintenance failure. For actual progression, options are limited. Maybe a PARPi-platinum combo? But that's not standard.
#
# Important caveat: this is ovarian cancer, not breast cancer. The user said "kidney cancer" in the initial context, but the case is clearly ovarian cancer. I must correct that upfront to avoid confusion. The question is about ovarian cancer treatment, not kidney cancer.
#
# For limitations: no randomized data for second-line PARPi, unknown resistance mechanisms, and no biomarker to predict response to rechallenge. I should stress that treatment decisions must be individualized.
#
# I'll structure the answer:
# 1) Clarify cancer type (ovarian, not kidney)
# 2) Explain why PARPi resistance matters
# 3) List evidence-based options with caveats
# 4) Discuss clinical trial considerations
# 5) Note the lack of platinum-sensitive recurrence options
# 6) Emphasize multidisciplinary discussion
#
# Must avoid giving specific drug names as recommendations - say "a PARP inhibitor" generically. And absolutely no fabricated stats. If I mention SOLO-2, I'll state it's for platinum-sensitive recurrence, which this patient likely isn't.
#
# The tone should be educational but precise. As an oncologist, I'd want to see this approach: mechanism → evidence → limitations. And always remind that guidelines evolve - NCCN updates quarterly.
# </think>
#
# ### Comprehensive Analysis: Next Treatment Options for BRCA1-Mutated Relapsed/Refractory High-Grade Serous Ovarian Cancer (HGSOC)
#
# **Critical Clarification:**
# The clinical scenario describes **high-grade serous ovarian cancer (HGSOC)**, *not* kidney cancer. BRCA1 mutations are characteristic of HGSOC (and breast cancer), not renal cell carcinoma. I will address the question as presented, focusing exclusively on ovarian cancer management. *If this were a kidney cancer case, the biology, standard treatments, and biomarkers would be entirely different (e.g., VHL mutations, VEGF inhibitors, immune checkpoint inhibitors).*
#
# ---
#
# ### I. Biological Mechanism & Resistance Context
# **Key Pathway:** BRCA1 mutations cause **homologous recombination deficiency (HRD)**, impairing DNA double-strand break repair. This makes tumors "synthetic lethal" to PARP inhibitors (PARPi), which trap PARP-DNA complexes and cause catastrophic DNA damage.
# **Progression After PARPi:** Resistance to PARPi in BRCA-mutated HGSOC typically arises from:
# - **Reversion mutations** in *BRCA1* (e.g., loss of wild-type allele)
# - **Upregulation of bypass pathways** (e.g., RAD51, RAD52, or alternative NHEJ)
# - **Loss of 53BP1/BRCA2** (less common in *BRCA1*-mutated tumors)
# - **Tumor evolution** to non-HRD phenotypes
# - **Pharmacokinetic limitations** (e.g., subtherapeutic drug levels)
#
# *Clinical implication:* Progression on PARPi suggests the tumor has evolved resistance, but the *specific mechanism* is unknown without re-biopsy. This limits options to those targeting residual HRD or alternative pathways.
#
# ---
#
# ### II. Evidence-Based Treatment Options (Per NCCN/ESMO Guidelines & Recent Data)
# *Note: All recommendations require multidisciplinary discussion (medical oncology, gynecologic oncology, genetic counseling) and consideration of patient-specific factors (performance status, comorbidities, prior treatment toxicity).*
#
# #### A. **Rechallenge with PARP Inhibitor (Limited Evidence)**
# - **Rationale:** If progression occurred on a specific PARPi (e.g., olaparib), switching to another agent (e.g., niraparib, rucaparib) *might* overcome resistance.
# - **Evidence:**
#   - **NOVA Trial (NCT02576455):** Niraparib maintenance after platinum response showed PFS benefit in *BRCA*-mutated HGSOC (HR 0.31; 95% CI 0.21–0.45). However, *no data exists for progression after PARPi*.
#   - **Small retrospective studies (e.g., *Gynecol Oncol* 2020;157:380-386):** Case series suggest ~15-20% response rate to second-line PARPi after primary PARPi failure, but this is **not practice-changing evidence** (Level 4 evidence).
# - **Clinical Application:**
#   - *Consider only if progression was documented with RECIST criteria and no new resistance mechanisms (e.g., reversion mutation) are suspected.*
#   - *Niraparib or rucaparib may be preferred over olaparib due to different resistance profiles.*
#   - **Critical caveat:** No randomized trials support this; efficacy is unproven. Toxicity (anemia, fatigue, myelosuppression) may be additive.
#
# #### B. **Clinical Trials (Highest Priority)**
# - **Rationale:** This is the most evidence-based approach for refractory *BRCA*-mutated HGSOC.
# - **Key Trial Categories:**
#   - **Novel PARPi combinations:**
#     - *NCT03336708 (SOLO-3):* Olaparib + bevacizumab (for platinum-sensitive recurrence; not applicable here, but may inform future trials)
#     - *NCT04475748:* Niraparib + pembrolizumab (exploring synergy in HRD tumors)
#   - **Targeting bypass pathways:**
#     - *NCT04537047:* RAD51 inhibitor + PARPi (preclinical data promising)
#     - *NCT03747747:* ATR inhibitor (e.g., ceralasertib) + PARPi (early phase)
#   - **Emerging PARPi:**
#     - *NCT04447442:* Elacestrant (SERD) + niraparib (for *BRCA*-mutated HGSOC)
# - **Evidence Quality:** Phase I/II trials (Level 3-4 evidence). **No phase III data exists for second-line PARPi.**
# - **Clinical Application:**
#   - *Referral to a gynecologic oncology center with trial access is essential.*
#   - *Must confirm tumor remains HRD (via genomic testing of new biopsy) before enrolling.*
#
# #### C. **Bevacizumab-Based Regimens (If Not Used Previously)**
# - **Rationale:** Anti-angiogenic therapy may overcome PARPi resistance.
# - **Evidence:**
#   - **GOG

# %% [markdown]
# ## 11. Verify Adapter (Cold Reload)
#
# Loads adapters from disk in a fresh model to confirm portability. Also verifies the DPO notebook can load these adapters.

# %%
import gc, torch, json
from pathlib import Path

del model, tokenizer, trainer, dataset
gc.collect()
torch.cuda.empty_cache()

print("Cleared training model from memory")
print(f"  Loading adapter from: {LORA_OUTPUT_DIR}")

from unsloth import FastLanguageModel

model2, tokenizer2 = FastLanguageModel.from_pretrained(
    model_name=LORA_OUTPUT_DIR,
    max_seq_length=MAX_SEQ_LENGTH,
    load_in_4bit=True,
)
model2.config._attn_implementation = "flash_attention_2"
FastLanguageModel.for_inference(model2)

with open(f"{LORA_OUTPUT_DIR}/oncologist_system_prompts.json") as f:
    reloaded_prompts = json.load(f)

test_cancer = list(reloaded_prompts.keys())[0]
test_system = reloaded_prompts[test_cancer]

messages = [
    {"role": "system", "content": test_system},
    {"role": "user", "content": TEST_PROMPT},
]

# Gemma 3 chat template
text = tokenizer2.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
)
inputs = tokenizer2(text, return_tensors="pt").to(model2.device)

outputs = model2.generate(
    **inputs,
    max_new_tokens=2048,
    temperature=0.7,
    top_p=0.8,
    do_sample=True,
)

response = tokenizer2.decode(outputs[0][inputs["input_ids"].shape[-1]:], skip_special_tokens=True)

print(f"\nADAPTER RELOAD TEST (cancer type: {test_cancer}):")
print(f"  Q: {TEST_PROMPT}")
print(f"  A: {response[:500]}")
print(f"\nAdapter loads cleanly from disk.")
print(f"DPO notebook (Phase 2) can now load this LoRA from: {LORA_OUTPUT_DIR}")

print(f"\nAdapter contents:")
for p in sorted(Path(LORA_OUTPUT_DIR).iterdir()):
    size_mb = p.stat().st_size / 1024 / 1024
    print(f"  {p.name:40s} {size_mb:>8.1f} MB")

del model2, tokenizer2, inputs, outputs
gc.collect()
torch.cuda.empty_cache()
# Out:
# Cleared training model from memory
#   Loading adapter from: /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters
# ==((====))==  Unsloth 2026.5.7: Fast Gemma3 patching. Transformers: 5.10.0.dev0.
#    \\   /|    NVIDIA GB10. Num GPUs = 1. Max memory: 121.689 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0a0+b558c986e8.nv25.11. CUDA: 12.1. CUDA Toolkit: 13.0. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33+aa7bc36.d20260302. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# /usr/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=579) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Loading weights:   0%|          | 0/808 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=2048) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ADAPTER RELOAD TEST (cancer type: cancerguide_treatment_reasoning):
#   Q: A 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer has progressed after platinum-based chemotherapy and a PARP inhibitor. What are the next treatment options?
#   A: <think>
# Okay, let me approach this systematically as a clinical oncologist. The patient is a 58-year-old woman with BRCA1-mutated high-grade serous ovarian cancer (HGSOC) who has progressed after platinum-based chemotherapy and a PARP inhibitor. This is a classic case where we need to consider maintenance therapy options beyond initial treatment.
#
# First, I need to recall the standard treatment sequence for BRCA-mutated HGSOC. Typically, first-line treatment is platinum-based chemo (like carbopla
#
# Adapter loads cleanly from disk.
# DPO notebook (Phase 2) can now load this LoRA from: /workspace/training/pubmed/output/v3/pubmed_oncologist_v3_medgemma_sft/lora_adapters
#
# Adapter contents:
#   README.md                                     0.0 MB
#   adapter_config.json                           0.0 MB
#   adapter_model.safetensors                   866.2 MB
#   chat_template.jinja                           0.0 MB
#   oncologist_system_prompts.json                0.0 MB
#   tokenizer.json                               31.8 MB
#   tokenizer.model                               4.5 MB
#   tokenizer_config.json                         1.1 MB
